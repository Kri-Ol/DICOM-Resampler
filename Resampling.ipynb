# %% [markdown]
# # DICOM images resampling

# %% [markdown]
# This notebook is dedicated to the 2D resampling of the DICOM patient images.

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# - Python 3.7.x, mine from Anaconda (5.3.1 x64 as of now, https://www.anaconda.com/download/)
# - conda update python numpy matplotlib scipy pandas bokeh
# - conda update pip
# - pip install pydicom (v1.2 as of now)
# - conda install plotly
# - conda install scikit-image (shall be in full Anaconda, if miniConda is installed, you have to install it)

# %%
# %matplotlib inline

import numpy as np
import pydicom
from pathlib import Path
import matplotlib.pyplot as plt
import scipy.ndimage
from skimage import morphology
from skimage import measure
from skimage.transform import resize

# %%
X = 0
Y = 1
Z = 2

def squared(x):
    return x*x

# %% [markdown]
# List directory and check and count files

# %%
#data_path = "D:/XCSW/Xciser/Bin/X64/Release/Export/Exported_XCISION-DM_Copy_The-Copy_1_201805100448"
data_path = "D:/Patients/Pt16_RP_20170515"
output_path = working_path = "."
output_dir  = "Out"

# here is new spacing to be resampled to
desired_spacing = [1.171875, 1.171875]

# new patient name and ID, not to mess with existing ones,
# if None will be left unchanged
PatientName = 'RP001R       ' #"XCISION^DMM" # = None
PatientID   = 'RP001R   '     #"7366473"     # = None

# new patient image orientation, if None will be left unchanged
theta = np.pi - 2./180.*np.pi
phi   = 0.0
PatientImageOrientation = [np.cos(theta), np.sin(theta)*np.cos(phi), np.sin(theta)*np.sin(phi),
                           -np.cos(theta-0.5*np.pi), np.sin(theta-0.5*np.pi)*np.cos(phi+np.pi), np.sin(theta-0.5*np.pi)*np.sin(phi+np.pi)]
PatientImageOrientation = np.round(PatientImageOrientation, 10) # round to float precision
print(f"Desired image orientation: {PatientImageOrientation}")
# uniformity check
PIOnorm = squared(PatientImageOrientation[0]) + squared(PatientImageOrientation[1]) + squared(PatientImageOrientation[2])
if PIOnorm > 1.000001 or PIOnorm < 0.999999:
    print("Something wornig with axis 0 of PatientImageOrientation")
PIOnorm = squared(PatientImageOrientation[3]) + squared(PatientImageOrientation[4]) + squared(PatientImageOrientation[5])
if PIOnorm > 1.000001 or PIOnorm < 0.999999:
    print("Something wornig with axis 1 of PatientImageOrientation")
# orthogonality check
print(PatientImageOrientation[0]*PatientImageOrientation[3] +
      PatientImageOrientation[1]*PatientImageOrientation[4] +
      PatientImageOrientation[2]*PatientImageOrientation[5]) 

l = list(Path(data_path).glob("*.dcm"))

# Print out the first 5 file names to verify we're in the right folder.
print("Total of {0} DICOM images.\nFirst 5 filenames:".format(len(l)))
for p in l[:5]:
    print(f"{p}")
# Out:
# Desired image orientation: [-0.99939083  0.0348995   0.         -0.0348995  -0.99939083  0.        ]
# 0.0
# Total of 251 DICOM images.
# First 5 filenames:
# D:\Patients\Pt16_RP_20170515\1.2.840.113704.1.111.2904.1494855084.10_0002_000001_14948551230000.dcm
# D:\Patients\Pt16_RP_20170515\1.2.840.113704.1.111.2904.1494855084.10_0002_000002_14948551230001.dcm
# D:\Patients\Pt16_RP_20170515\1.2.840.113704.1.111.2904.1494855084.10_0002_000003_14948551230002.dcm
# D:\Patients\Pt16_RP_20170515\1.2.840.113704.1.111.2904.1494855084.10_0002_000004_14948551230003.dcm
# D:\Patients\Pt16_RP_20170515\1.2.840.113704.1.111.2904.1494855084.10_0002_000005_14948551240004.dcm

# %% [markdown]
# Load all scans, set thickness

# %%
def load_scans(path):
    """Here we assume equidistant in Z slices,
       sort output by InstanceNumber"""
    p = Path(path)
    slices = [pydicom.dcmread(str(Path(path)/s)) for s in p.iterdir() if s.is_file()]
    slices.sort(key = lambda x: int(x.InstanceNumber))
    try:
        slice_thickness = np.fabs(slices[0].ImagePositionPatient[2] - slices[1].ImagePositionPatient[2])
    except:
        slice_thickness = np.fabs(slices[0].SliceLocation - slices[1].SliceLocation)
        
    #for s in slices: # assign all slices the same thickness
    #    s.SliceThickness = slice_thickness
        
    return slices

id = 0
patient = load_scans(data_path)

# ok, put all images together into 3d matrix, test images dimensions as well
images  = np.stack([s.pixel_array for s in patient], axis = Z) # so final set of images would be (512,512,168)
print(f"All images together: {images.shape}")
print(patient[0]) # info from the first slice
# Out:
# All images together: (512, 512, 251)
# (0008, 0000) Group Length                        UL: 682
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'HELIX']
# (0008, 0012) Instance Creation Date              DA: '20170515'
# (0008, 0013) Instance Creation Time              TM: '093210'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113704.1.111.10036.1494855130.214
# (0008, 0020) Study Date                          DA: '20170515'
# (0008, 0022) Acquisition Date                    DA: '20170515'
# (0008, 0023) Content Date                        DA: '20170515'
# (0008, 002a) Acquisition DateTime                DT: '20170515093137-0400'
# (0008, 0030) Study Time                          TM: '092926'
# (0008, 0032) Acquisition Time                    TM: '093137'
# (0008, 0033) Content Time                        TM: '093137.881001'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'Philips'
# (0008, 0080) Institution Name                    LO: '                 '
# (0008, 0081) Institution Address                 ST: 'Baltimore, MD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: '         '
# (0008, 1030) Study Description                   LO: 'RT BREAST GPOD'
# (0008, 103e) Series Description                  LO: ''
# (0008, 1040) Institutional Department Name       LO: 'Radiation Oncology'
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Brilliance Big Bore'
# (0008, 1140)  Referenced Image Sequence   2 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113704.1.111.10036.1494855003.11
#    ---------
#    (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.840.113704.1.111.10036.1494855039.12
#    ---------
# (0010, 0000) Group Length                        UL: 86
# (0010, 0010) Patient's Name                      PN: 'RP001        '
# (0010, 0020) Patient ID                          LO: 'RP001    '
# (0010, 0030) Patient's Birth Date                DA: '19570102'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '060Y'
# (0010, 2000) Medical Alerts                      LO: ''
# (0018, 0000) Group Length                        UL: 356
# (0018, 0022) Scan Options                        CS: 'HELIX'
# (0018, 0050) Slice Thickness                     DS: "1.00"
# (0018, 0060) KVP                                 DS: "120"
# (0018, 0088) Spacing Between Slices              DS: "-1.0"
# (0018, 0090) Data Collection Diameter            DS: "600"
# (0018, 1020) Software Version(s)                 LO: '3.5.5'
# (0018, 1030) Protocol Name                       LO: 'GAMMAPOD/OncoBody'
# (0018, 1100) Reconstruction Diameter             DS: "600"
# (0018, 1120) Gantry/Detector Tilt                DS: "0"
# (0018, 1130) Table Height                        DS: "134.000000"
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: "1090"
# (0018, 1151) X-Ray Tube Current                  IS: "321"
# (0018, 1152) Exposure                            IS: "350"
# (0018, 1160) Filter Type                         SH: 'C'
# (0018, 1210) Convolution Kernel                  SH: 'C'
# (0018, 5100) Patient Position                    CS: 'HFP'
# (0018, 9321)  CT Exposure Sequence   1 item(s) ----
#    (0018, 9323) Exposure Modulation Type            CS: 'NONE'
#    (0018, 9324) Estimated Dose Saving               FD: 0.0
#    (0018, 9328) Exposure Time in ms                 FD: 1.0903426791277258
#    (0018, 9330) X-Ray Tube Current in mA            FD: 321.0
#    (0018, 9332) Exposure in mAs                     FD: 350.0
#    (0018, 9345) CTDIvol                             FD: 23.2
#    ---------
# (0018, 9323) Exposure Modulation Type            CS: 'NONE'
# (0018, 9345) CTDIvol                             FD: 23.2
# (0020, 0000) Group Length                        UL: 266
# (0020, 000d) Study Instance UID                  UI: 1.2.840.113704.1.111.3080.1494854934.5
# (0020, 000e) Series Instance UID                 UI: 1.2.840.113704.1.111.2904.1494855084.10
# (0020, 0010) Study ID                            SH: '16888'
# (0020, 0011) Series Number                       IS: "2"
# (0020, 0012) Acquisition Number                  IS: ''
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0032) Image Position (Patient)            DS: ['-317', '216', '-1187.5']
# (0020, 0037) Image Orientation (Patient)         DS: ['1', '0', '0', '0', '-1', '0']
# (0020, 0052) Frame of Reference UID              UI: 1.2.840.113704.1.111.2904.1494854972.4
# (0020, 0060) Laterality                          CS: ''
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: "-1187.50"
# (0020, 4000) Image Comments                      LT: ''
# (0028, 0000) Group Length                        UL: 180
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['1.171875', '1.171875']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 1050) Window Center                       DS: ['00060', '00060']
# (0028, 1051) Window Width                        DS: ['00400', '00400']
# (0028, 1052) Rescale Intercept                   DS: "-1024"
# (0028, 1053) Rescale Slope                       DS: "1"
# (0032, 0000) Group Length                        UL: 8
# (0032, 1070) Requested Contrast Agent            LO: ''
# (0040, 0000) Group Length                        UL: 22
# (0040, 0012) Pre-Medication                      LO: ''
# (0040, 0253) Performed Procedure Step ID         SH: '168884'
# (00e1, 0000) Private Creator                     UN: b'\xb0\x00\x00\x00'
# (00e1, 0010) Private tag data                    LO: 'ELSCINT1'
# (00e1, 1001) [Data Dictionary Version]           UN: b'\x01\x00'
# (00e1, 1002) Private tag data                    UN: b'Age3'
# (00e1, 1022) [Presentation Relative Center]      UN: b'00000\\00000 '
# (00e1, 1023) [Presentation Relative Part]        UN: b'00001\\00001 '
# (00e1, 1036) Private tag data                    UN: b'NO'
# (00e1, 1042) [Unknown]                           UN: b'453567-129831 '
# (00e1, 1050) [Acquisition Duration]              UN: b'24.478'
# (00e1, 1061) [Protocol File Name]                UN: b'OncoBody_Multi_1054_usr.proc'
# (00e1, 1063) [Patient Language]                  UN: b'ENGLISH '
# (01e1, 0000) Private Creator                     UN: b'\xa4\x00\x00\x00'
# (01e1, 0010) Private tag data                    LO: 'ELSCINT1'
# (01e1, 1041) Private tag data                    UN: b'\xe1\x01\x18\x00\xf7\x01^\x00\xf7\x01P\x00\xf7\x01Q\x00\xf7\x01R\x00\xf7\x01S\x00\xf7\x01T\x00\xf7\x01U\x00\xf7\x01V\x00\xf7\x01W\x00\xf7\x01X\x00\xf7\x01Y\x00\xf7\x01Z\x00\xf7\x01[\x00\xf7\x01\\\x00\xf7\x01_\x00\xf7\x01`\x00\xf7\x01a\x00\xf7\x01b\x00\xf7\x01c\x00\xf7\x01d\x00\xf7\x01e\x00\xf7\x01f\x00\xf7\x01g\x00\xf7\x01q\x00\xf7\x01r\x00\xf7\x01z\x00\xf7\x01\x81\x00\xf7\x01\x87\x00\xf7\x01\x8d\x00\xf7\x01\x96\x00\xf7\x01\x98\x00\xe1\x00\x82\x00\xe1\x00\xc5\x00\xe1\x00\xc3\x00'
# (01f1, 0000) Private Creator                     UN: b'\xc6\x03\x00\x00'
# (01f1, 0010) Private tag data                    LO: 'ELSCINT1'
# (01f1, 1001) [Acquisition Type]                  UN: b'SPIRAL'
# (01f1, 1002) [Unknown]                           UN: b'STANDARD'
# (01f1, 1003) [Concurrent Slices Generation]      UN: b''
# (01f1, 1004) [Angular Sampling Density]          UN: b'NORMAL'
# (01f1, 1005) [Reconstruction Arc]                UN: b'180 '
# (01f1, 1007) [Table Velocity]                    UN: b'11.00 '
# (01f1, 1008) [Acquisition Length]                UN: b'251 '
# (01f1, 100a) [Edge Enhancement Weight]           UN: b'\x00\x00'
# (01f1, 100c) [Scanner Relative Center]           UN: b'0.0616666675\\-0.0283333343'
# (01f1, 100d) [Rotation Angle]                    UN: b'0 '
# (01f1, 100e) [Unknown]                           UN: b'\x00\x00\x00\x00'
# (01f1, 1026) [Pitch]                             UN: b'0.688 '
# (01f1, 1027) [Rotation Time]                     UN: b'0.75'
# (01f1, 1032) [Image View Convention]             UN: b'RIGHT_ON_LEFT '
# (01f1, 1042) [Unknown]                           UN: b'No'
# (01f1, 1044) [Unknown]                           UN: b'\xaa\xaa\xaa\xaa\x15\x00\x00\x00\x06\x00\x00\x00\x01\x00\x00\x00-\x10\x00\x00\xc84\x08\x002\x00\x00\x00\x01\x00\x00\x00$\x0b\x00\x00(\x02\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x00\x00\x00\xec\r\x00\x00l\x00\x00\x00\x05\x00\x00\x00d\x0e\x00\x00\xbc\x00\x00\x00\x06\x00\x00\x00,\x0f\x00\x00(\x00\x00\x00\x07\x00\x00\x00`\x0f\x00\x00\x08\x00\x00\x00\x08\x00\x00\x00\xe8"\x00\x00$\x00\x00\x00\t\x00\x00\x00t\x0f\x00\x00\xe4\x00\x00\x00\n\x00\x00\x00d\x10\x00\x00p\x08\x00\x00\x0b\x00\x00\x00\xdc$\x00\x00$\x00\x00\x00\x0c\x00\x00\x00\x08\x19\x00\x00\xd0\x06\x00\x00\r\x00\x00\x00\xe0\x18\x00\x00\x1c\x00\x00\x00\x0e\x00\x00\x00\xdc!\x00\x00\x94\x00\x00\x00\x0f\x00\x00\x00\x18#\x00\x00\xb8\x01\x00\x00\x10\x00\x00\x00\xe4\x1f\x00\x00t\x00\x00\x00\x11\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x12\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x13\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x14\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x15\x00\x00\x00d \x00\x00l\x01\x00\x00\x16\x00\x00\x00x"\x00\x00<\x00\x00\x00\x17\x00\x00\x00\x0e\x03\x00\x00<\x00\x00\x00\x18\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x19\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x1a\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x1b\x00\x00\x00\xd8\'\x00\x00|\x00\x00\x00\x1c\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x1d\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x1e\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x1f\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00 \x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00!\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00"\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00#\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00$\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00%\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00&\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00(\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00)\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00*\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00+\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00,\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00-\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00.\x00\x00\x00`(\x00\x00 \x05\x00\x00/\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x000\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00 A\x00\x00\x00\x00\x05\x00\x00\x00\x00\x00\x00\x00'
# (01f1, 1046) [Unknown]                           UN: b'\x00\x00@?'
# (01f1, 1047) [Unknown]                           UN: b'3D'
# (01f1, 1049) [Unknown]                           UN: b'350 '
# (01f1, 104a) [Unknown]                           UN: b'NONE'
# (01f1, 104b) [Unknown]                           UN: b'16x0.75 '
# (01f1, 104d) [Unknown]                           UN: b'NO'
# (01f1, 104e) [Unknown]                           UN: b'Body'
# (01f7, 0000) Private Creator                     UN: b'\x04)\x00\x00'
# (01f7, 0010) Private tag data                    LO: 'ELSCINT1'
# (01f7, 1010) [Unknown]                           UN: b''
# (01f7, 1011) [Unknown]                           UN: b'\x81\xf9\x00\x00A\x01\x00\x00x\x00\x00\x00x\x00\x00\x00\x01\x00\x00\x00\x01\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x01\x00\x00\x00\x10\x00\x00\x00\x00\x00@?\x02\x00\x00\x00\x05\x00\x00\x00\x02\x00\x00\x00\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xff\xcd\xcc\x8c?\x9a\x99\x99??\x01\x00\x00\x00\x86\x00\x00\x00$H8D\x9c\xa2\x1bA\x9c\xa2\x1b\xc1\x00\x004CK\xa8\x00\x00\xff\x8d\x02B\x00\x00\xb4C\x9f_\x00\x00\xee\x02\x00\x00\x01\x00\x00\x00\x00\x000A\x00\xc0\x86C\xff\xff\xff\xff\x01\x00\x00\x00\x00\x00\x80\xbf\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x01\x00\x00\x00XTrackPosDetTab\x00site\\ScanSyspar.cfg\x00S.cfg\x00 Part" \r\neye-phantom =\x00\x00\x00\x00\x00ow \r\n\r\n; head centering: the default is yes\r\n; to disable use v\x01\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80?\x00\x00\x00\x00\x00\x00\x00\x00\x14\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x80\xbe\x00\x00\x80>\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# (01f7, 1013) [Unknown]                           UN: b'C:/usr/diamond.root/cfg/voice/ENGLISH\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00none\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00none\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00none\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xb4C\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\n\x00\x00\x00\n\x00\x00\x00\n\x00\x00\x00\x9a\xd95D\x00\x00\x80\xbf\xfb\x00\x00\x00\n\x00\x00\x00\x00.75mm_120kV_0.75sec_dr_sfs.tbl\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00(\x04\x00\x00\x08\x01\x00\x00C:\\usr\\diamond.root\\private_cfg\\RS_ClientOpt\x00ons.cfg\x00S.cfg\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\n\x00\x00\x00\x9a\x99!A\x9a\x99!A\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00Wedge_120kV_1FFS\x00tbl\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00inChannelCorTab\ ...
# (01f7, 101a) [Unknown]                           UN: b'\x8f\xc21A`\x06\x00\x00\x03\x00\x00\x00\x0b\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00'
# (01f7, 101b) [Unknown]                           UN: b'0\x03\x00\x00airS_standard_16x0.75mm_120kV_0.75sec_dr_dfs.tbl\n\x00\x00\x00\x9a\x99!A\x9a\x99!A\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00Wedge_120kV_2FFS.tbl\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\n\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00inChannelCorTab\x00\x00\x00\x00\xf8\x1d\x00\x00z\x08\x00\x00$\x16d\x04\xf4\x7fd\x04\x01\x00\x00\x00\x01\x00\x00\x00RawFile\x00\n; Yes/No - \x00uadChannelCorTab\x00nable = Yes \r\n; Yes/No - dPrepFile\x00\r\nOncology-LnLut.tbl\x00le = Yes \r\nDFS_TYPE = 2 \r\n; Sagi: ReconFile\x00ta3 only: BadDet_16x0.75.tbl\x00: "Pulmo sensor device" wImageFile\x00nce pu\xf0\x02\x00\x00\x00\x00\x00\x00EwLayersWeightsTab\x00ent software\r\n;------------------------------q=bAq=bAq=bA1\x08\xac<_)K\xbbr3\\9\x00\x00\x00\x00\x00\x00\x00\x00@B\x0f\x00\x9f\xab\xad\xbb\x89\xd2\xde:9\x00\x00\x8f\xc2u=\xaeGa=\x1b\x00\x00\x00\xcd\xcc\xcc<\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x00\x00\x00\x0c\x00\x00\x00\x00\x00\xc0?\x00\x00@@ff\x86?\x01\x00\x00\x00\x00\x00\x00\x00\x00gin (options: yes,no nominal:yes)\r\ninit-raw-list = yes\r\n\r\n; sav\x00-recon : (options: yes,no)\r\n; yes - Irs server write image/prep data from IRS to file (for debug)\r\nsave-recon = no\r\n; max-prep-size-to-save - size in Mbyte\x10\x05\x00\x000\x02\x00\x00Phantom_120kV_WLarge_FullFlt_0.75mm_DFSX_Std.tbl\x00\x00\x00\x00\x10\x00\x00\x00\x00\x00@?\x02\x00\x00\x00\n\x00\x00\x00t\x8c\x9a\x00\xd0B*\x04X\xe6\x12\x00\xd0B*\x04\x84\xe6\x12\x00Z\xf8\x9a\x00\xa7\xe6\x12\x00\x01\x00\x00\x00,?\x00\x00\x00\x00\x86\x00\x00\x00$H8D\x9c\xa2\x1bA\x9c\xa2\x1b\xc1\x00\x004CK\xa8\x00\x00\xff\x8d\x02B\x00\x00\xb4C\x9f_\x00\x00\xee\x02\x00\x00\x01\x00\x00\x00\x00\x000A\x00\xc0\x86C\xff\xff\xff\xff\x01\x00\x00\x00\x00\x00\x80\xbf\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\
x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00`\t\xf5@\x00\x00\x00\x00h\x01\x00\x00\xcb\x1c\x00\x00\x89\n\x00\x00\x00\x00\x00\x00\x00t\xa3@\x80\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf0?L\x04\x00\x00&\x12\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x ...
# (07a1, 0000) Private Creator                     UN: b'\x1c\x00\x00\x00'
# (07a1, 0010) Private tag data                    LO: 'ELSCINT1'
# (07a1, 1010) [Tamar Software Version]            UN: b'3.5 '
# (7fdf, 0000) Private Creator                     UN: b' \x00\x00\x00'
# (7fdf, 0010) Private tag data                    LO: 'ELSCINT1'
# (7fdf, 10f0) [Unknown]                           UN: b''
# (7fdf, 10ff) [Unknown]                           UN: b''
# (7fe0, 0000) Group Length                        UL: 524296
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes

# %% [markdown]
# Some good checks on what we got there

# %%
sth = patient[0].SliceThickness
print(f"Slice Thickness: {sth}")
px0 = patient[0].PixelSpacing[X]
px1 = patient[0].PixelSpacing[Y]
print(f"Pixel Spacing (row, col): ({px0}, {px1})")
# Out:
# Slice Thickness: 1.00
# Pixel Spacing (row, col): (1.171875, 1.171875)

# %% [markdown]
# More checks - slopes, intercepts, slice positions etc

# %%
for k, slice in enumerate(patient):
    minpix = np.min(slice.pixel_array.astype(np.int16))
    maxpix = np.max(slice.pixel_array.astype(np.int16))
    if minpix < 0:
        print(f"Negative value discovered: {k}")
        break
    if maxpix > 4095: # 12 bits scanner
        print(f"12-Positive value discovered:{k}")
        break
        
# now test for different pixel sizes
vx_prev = patient[0].PixelSpacing[X]
vy_prev = patient[0].PixelSpacing[Y]

for k, slice in enumerate(patient):
    vx = slice.PixelSpacing[X]
    vy = slice.PixelSpacing[Y]
    if np.fabs(vx - vx_prev) > 0.001:
        print(f"X pixel values are different:{k}")
        break
    if np.fabs(vy - vy_prev) > 0.001:
        print(f"Y pixel values are different:{k}")
        break
    vy_prev = vy
    vx_prev = vx
    
# now test for slope/intercept
slope_prev = patient[0].RescaleSlope
intrc_prev = patient[0].RescaleIntercept
for k, slice in enumerate(patient):
    slope = slice.RescaleSlope
    intrc = slice.RescaleIntercept
    if np.fabs(slope - slope_prev) > 0.001:
        print(f"Slope values are different:{k}")
        break
    if np.fabs(intrc - intrc_prev) > 0.001:
        print(f"Intercept values are different:{k}")
        break
    intrc_prev = intrc
    slope_prev = slope
    
# now test for position/thickness
patientpos_prev = None
sliceths_prev   = None
sliceloc_prev   = None
for k, slice in enumerate(patient):
    sliceths = slice.SliceThickness
    sliceloc = slice.SliceLocation
    
    if np.fabs( sliceloc - slice.ImagePositionPatient[Z] ) > 0.001:
        print(f"Slice position and patient position are different:{k}")
        break
        
    if k != 0:
        t1 = np.fabs(slice.ImagePositionPatient[Z] - patientpos_prev[Z]) # might be negative
        t2 = sliceths 
        t3 = np.fabs(sliceloc - sliceloc_prev) # might be negative
        
        if np.fabs(t1 - t2) > 0.001:
            print(f"Thickness from SliceThickness and PatientPosition are different:{k}")
        if np.fabs(t1 - t3) > 0.001:
            print(f"Thickness from SliceThickness and SliceLocation are different:{k}")
        
    patientpos_prev = slice.ImagePositionPatient
    sliceths_prev   = sliceths
    sliceloc_prev   = sliceloc

# %%
np.save(str(Path(output_path)/f"fullimages_{id}.npy"), images)

# %%
file_used = str(Path(output_path)/f"fullimages_{id}.npy")
imgs_to_process = np.load(file_used).astype(np.float64) 

plt.hist(imgs_to_process.flatten(), bins=50, color='c')
plt.xlabel("Voxel values")
plt.ylabel("Frequency")
plt.show()

# %%
id = 0
imgs_to_process = np.load(file_used)

def sample_stack(stack, rows=13, cols=10, start_with=0, show_every=2):
    fig,ax = plt.subplots(rows, cols, figsize=[24, 24])
    last = False
    for ir in range(rows):
        for ic in range(cols):
            ind = start_with + (ir*cols + ic)*show_every
            if ind > stack.shape[Z] - 1:
                ind = stack.shape[Z] - 1
                last = True
            
            ax[ir, ic].set_title(f"slice {ind}")
            ax[ir, ic].imshow(stack[:,:,ind], cmap = "gray")
            ax[ir, ic].axis("off")
            if last:
                break
    plt.show()

sample_stack(imgs_to_process)

# %%
id = 0
imgs_to_process = np.load(file_used)

def resample2d(image, scan, new_spacing):
    # Determine current pixel spacing
    spacing = map(float, [scan[0].PixelSpacing[X], scan[0].PixelSpacing[Y], scan[0].SliceThickness])
    spacing = np.array(list(spacing))

    resize_x    = spacing[X] / new_spacing[X]
    new_shape_x = np.round(image.shape[X] * resize_x)
    resize_x    = float(new_shape_x) / float(image.shape[X])
    sx = spacing[X] / resize_x

    resize_y    = spacing[Y] / new_spacing[Y]
    new_shape_y = np.round(image.shape[Y] * resize_y)
    resize_y    = new_shape_y / image.shape[Y]
    sy = spacing[Y] / resize_y
    
    image = scipy.ndimage.interpolation.zoom(image, (resize_x, resize_y, 1.0), order=1)
    
    return (image, (sx, sy))

print(f"Shape before resampling\t{imgs_to_process.shape}")
imgs_after_resamp, spacing = resample2d(imgs_to_process, patient, desired_spacing)
print(f"Shape after resampling:\t{imgs_after_resamp.shape}")
print(f"New spacing: {spacing}")
# Out:
# Shape before resampling	(512, 512, 251)
# Shape after resampling:	(512, 512, 251)
# New spacing: (1.171875, 1.171875)

# %%
for i, slice in enumerate(patient):
    q = imgs_after_resamp[:, :, i]
    slice.PixelData = q.tobytes()
    slice.PixelSpacing[X] = np.round(spacing[X], decimals=3)
    slice.PixelSpacing[Y] = np.round(spacing[Y], decimals=3)
    slice.Rows, slice.Columns = q.shape
    slice.PatientName = slice.PatientName if PatientName is None else PatientName
    slice.PatientID   = slice.PatientID if PatientID is None else PatientID
    if PatientImageOrientation is not None:
        slice.ImageOrientationPatient[0] = PatientImageOrientation[0]
        slice.ImageOrientationPatient[1] = PatientImageOrientation[1]
        slice.ImageOrientationPatient[2] = PatientImageOrientation[2]
        slice.ImageOrientationPatient[3] = PatientImageOrientation[3]
        slice.ImageOrientationPatient[4] = PatientImageOrientation[4]
        slice.ImageOrientationPatient[5] = PatientImageOrientation[5]
    fname = Path(output_dir)/(slice.SeriesInstanceUID + "_" + str(slice.InstanceNumber) + ".dcm")
    pydicom.dcmwrite(str(fname), slice, False)
print("Done!")
# Out:
# Done!

# %% [markdown]
# Check output directory for images

# %% [markdown]
# ### References

# %% [markdown]
# Inspired by https://www.raddq.com/dicom-processing-segmentation-visualization-in-python/.
